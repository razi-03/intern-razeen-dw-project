# %%
# Read the CSV file from the Lakehouse Files folder

df = spark.read.format("csv") \
    .option("header", "true") \
    .option("inferSchema", "true") \
    .load("Files/SampleSuperstore.csv")

display(df)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 3, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 6d880949-a4b4-4d75-bf7c-0cc0f59a1283)

# %%
# Display the schema (column names and data types)

df.printSchema()
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 4, Finished, Available, Finished, False)
# root
#  |-- Ship Mode: string (nullable = true)
#  |-- Segment: string (nullable = true)
#  |-- Country: string (nullable = true)
#  |-- City: string (nullable = true)
#  |-- State: string (nullable = true)
#  |-- Postal Code: integer (nullable = true)
#  |-- Region: string (nullable = true)
#  |-- Category: string (nullable = true)
#  |-- Sub-Category: string (nullable = true)
#  |-- Sales: double (nullable = true)
#  |-- Quantity: integer (nullable = true)
#  |-- Discount: double (nullable = true)
#  |-- Profit: double (nullable = true)

# %%
from pyspark.sql.functions import col

bronze_df = df.select(
    col("Ship Mode").alias("ship_mode"),
    col("Segment").alias("segment"),
    col("Country").alias("country"),
    col("City").alias("city"),
    col("State").alias("state"),
    col("Postal Code").alias("postal_code"),
    col("Region").alias("region"),
    col("Category").alias("category"),
    col("Sub-Category").alias("sub_category"),
    col("Sales").alias("sales"),
    col("Quantity").alias("quantity"),
    col("Discount").alias("discount"),
    col("Profit").alias("profit")
)

display(bronze_df)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 161ec3b2-ec2b-4b15-b632-5933b599e247)

# %%
bronze_df.write \
    .mode("overwrite") \
    .format("delta") \
    .saveAsTable("bronze_superstore")
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 6, Finished, Available, Finished, False)

# %%
bronze = spark.table("bronze_superstore")

display(bronze)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 8e85e913-b4a9-4ffe-b90c-0eab0619c8f0)

# %%
bronze = spark.table("bronze_superstore")

display(bronze)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e220f7ef-70fb-4b7a-80ad-a6aedea8ed81)

# %%
bronze = spark.table("bronze_superstore")

print("Row Count:", bronze.count())
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 9, Finished, Available, Finished, False)
# Row Count: 9994

# %%
bronze = spark.table("bronze_superstore")

display(bronze)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e0ad3f28-17eb-4a50-a72d-68a4feabadf3)

# %%
spark.sql("SHOW TABLES").show(truncate=False)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 11, Finished, Available, Finished, False)
# +-----------------------------------------------------+-----------------+-----------+
# |namespace                                            |tableName        |isTemporary|
# +-----------------------------------------------------+-----------------+-----------+
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|bronze_superstore|false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_category     |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_date         |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_region       |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_segment      |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_shipmode     |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|fact_sales       |false      |
# ...

# %%
print(spark.catalog.currentDatabase())
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 12, Finished, Available, Finished, False)
# chimcobldhq2akrle1in4srkdtp6a824c5q62825dpjmirj5clp6irj74l9nas35e9pn8rricl662qr5d1nnasr54li64ro

# %%
spark.sql("DESCRIBE TABLE bronze_superstore").show(truncate=False)
# Out:
# StatementMeta(, cee5ab98-e628-4b7f-8e8a-e37a83553a12, 13, Finished, Available, Finished, False)
# +------------+---------+-------+
# |col_name    |data_type|comment|
# +------------+---------+-------+
# |ship_mode   |string   |NULL   |
# |segment     |string   |NULL   |
# |country     |string   |NULL   |
# |city        |string   |NULL   |
# |state       |string   |NULL   |
# |postal_code |int      |NULL   |
# |region      |string   |NULL   |
# |category    |string   |NULL   |
# |sub_category|string   |NULL   |
# |sales       |double   |NULL   |
# |quantity    |int      |NULL   |
# |discount    |double   |NULL   |
# |profit      |double   |NULL   |
# +------------+---------+-------+
