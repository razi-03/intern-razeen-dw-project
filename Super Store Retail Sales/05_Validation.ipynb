# %%
bronze = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.bronze_superstore"
)

silver = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.silver_superstore"
)

fact = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.fact_sales"
)
# Out:
# StatementMeta(, d0830c75-124d-4222-952e-73643aa4b581, 3, Finished, Available, Finished, False)

# %%
print("Bronze:", bronze.count())
print("Silver:", silver.count())
print("Fact:", fact.count())
# Out:
# StatementMeta(, d0830c75-124d-4222-952e-73643aa4b581, 4, Finished, Available, Finished, False)
# Bronze: 9994
# Silver: 9977
# Fact: 9977

# %%
bronze.printSchema()
silver.printSchema()
fact.printSchema()
# Out:
# StatementMeta(, d0830c75-124d-4222-952e-73643aa4b581, 5, Finished, Available, Finished, False)
# root
#  |-- ship_mode: string (nullable = true)
#  |-- segment: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- category: string (nullable = true)
#  |-- sub_category: string (nullable = true)
#  |-- sales: double (nullable = true)
#  |-- quantity: integer (nullable = true)
#  |-- discount: double (nullable = true)
#  |-- profit: double (nullable = true)
#
# root
#  |-- ship_mode: string (nullable = true)
#  |-- segment: string (nullable = true)
#  |-- country: string (nullable = true)
#  |-- city: string (nullable = true)
#  |-- state: string (nullable = true)
#  |-- postal_code: integer (nullable = true)
#  |-- region: string (nullable = true)
#  |-- category: string (nullable = true)
# ...

# %%
display(bronze)
display(silver)
display(fact)
# Out:
# StatementMeta(, d0830c75-124d-4222-952e-73643aa4b581, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, ba2ddccc-f763-4142-9335-61d3533959b4)
# SynapseWidget(Synapse.DataFrame, 4b35523b-b7c8-430a-b50b-60192c31899d)
# SynapseWidget(Synapse.DataFrame, 12c562e6-738d-436d-aa91-39f0c9f214a3)

# %%
spark.sql("SHOW TABLES").show(truncate=False)
# Out:
# StatementMeta(, d0830c75-124d-4222-952e-73643aa4b581, 7, Finished, Available, Finished, False)
# +-----------------------------------------------------+-----------------+-----------+
# |namespace                                            |tableName        |isTemporary|
# +-----------------------------------------------------+-----------------+-----------+
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|bronze_superstore|false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_category     |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_date         |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_region       |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_segment      |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|dim_shipmode     |false      |
# |`Superstore Data Engineering`.SuperstoreLakehouse.dbo|fact_sales       |false      |
# ...
