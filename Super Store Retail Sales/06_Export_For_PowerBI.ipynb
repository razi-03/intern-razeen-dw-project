# %%
fact_sales = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.fact_sales"
)

dim_category = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.dim_category"
)

dim_region = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.dim_region"
)

dim_segment = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.dim_segment"
)

dim_shipmode = spark.table(
    "`Superstore Data Engineering`.SuperstoreLakehouse.dbo.dim_shipmode"
)
# Out:
# StatementMeta(, 5b189e47-396b-4bcf-9bd7-6fd33b496cad, 21, Finished, Available, Finished, False)

# %%
fact_sales.coalesce(1).write \
.mode("overwrite") \
.option("header", True) \
.csv("Files/PowerBI/fact_sales")
# Out:
# StatementMeta(, 5b189e47-396b-4bcf-9bd7-6fd33b496cad, 22, Finished, Available, Finished, False)
